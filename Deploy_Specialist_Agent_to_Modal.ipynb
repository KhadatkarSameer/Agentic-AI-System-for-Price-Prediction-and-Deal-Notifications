# %%
# import modal
import modal

# %%
# !modal setup

# %%
import os

# %%
os.environ['PYTHONIOENCODING'] = 'utf-8'

# %%
# !modal deploy pricer_service
# Out:
# â”Œâ”€ Modal Deprecation Warning (2025-02-06) â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”�
# â”‚ Using Python module paths will require using the -m flag in a future        â”‚
# â”‚ version of Modal.                                                           â”‚
# â”‚ Use `modal deploy -m pricer_service` instead.                               â”‚
# â””â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”˜
# â”Œâ”€ Modal Deprecation Warning (2025-01-15) â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”�
# â”‚ The `@modal.build` decorator is deprecated and will be removed in a future  â”‚
# â”‚ release.                                                                    â”‚
# â”‚                                                                             â”‚
# â”‚ We now recommend storing large assets (such as model weights) using a       â”‚
# â”‚ `modal.Volume` instead of writing them directly into the `modal.Image`      â”‚
# â”‚ filesystem. For other use cases we recommend using `Image.run_function`     â”‚
# â”‚ instead.                                                                    â”‚
# â”‚                                                                             â”‚
# â”‚ See https://modal.com/docs/guide/modal-1-0-migration for more information.  â”‚
# â”‚                                                                             â”‚
# â”‚ Source:                                                                     â”‚
# â”‚ F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:29       â”‚
# â”‚   @modal.build()                                                            â”‚
# â””â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”˜
# - Creating objects...
# \ Creating objects...
# / Creating objects...
# â””â”€â”€ -
# | Creating objects...
# â””â”€â”€ | Creating mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:
#     Uploaded 0/1 files
# - Creating objects...
# â””â”€â”€ - Creating mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:
#     Uploaded 0/1 files
# | Creating objects...
# â””â”€â”€ | Creating mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:
#     Finalizing index of 1 files
# - Creating objects...
# â””â”€â”€ - Creating mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:
#     Finalizing index of 1 files
# \ Creating objects...
# â””â”€â”€ \ Creating mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:
#     Finalizing index of 1 files
# / Creating objects...
# â””â”€â”€ - Creating mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py:
#     Finalizing index of 1 files
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Building image im-NHc3YxxxglyyFUZE63QNVQ
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#
# => Step 0: FROM base
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting huggingface
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting triton==3.3.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.1->torch) (65.5.1)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting charset_normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 67.0/67.0 MB 257.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl (411 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 821.2/821.2 MB 326.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 393.1/393.1 MB 151.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 8.9/8.9 MB 346.5 MB/s eta 0:00:00
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 23.7/23.7 MB 359.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 897.7/897.7 kB 429.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 571.0/571.0 MB 318.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 200.2/200.2 MB 378.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 1.1/1.1 MB 319.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 56.3/56.3 MB 385.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 158.2/158.2 MB 352.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 216.6/216.6 MB 394.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 156.8/156.8 MB 369.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 201.3/201.3 MB 402.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 19.7/19.7 MB 369.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 155.7/155.7 MB 384.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl (10.5 MB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 10.5/10.5 MB 381.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 16.9/16.9 MB 408.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 763.0/763.0 kB 490.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 792.7/792.7 kB 93.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 6.3/6.3 MB 286.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 3.0/3.0 MB 354.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 2.0/2.0 MB 429.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.4-py3-none-any.whl (64 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 4.8/4.8 MB 389.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
#    â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”�â”� 536.2/536.2 kB 804.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# \ Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset_normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# / Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# | Creating objects...
# â””â”€â”€ ðŸ”¨ Created mount
#     F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# - Creating objects...
# ...
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# Image saved, took 77.87s
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# Finished image build for im-eyug8m5tdfdLTeF3ZzptUf
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_se
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â””â”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ - Creating function Pricer.*...
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ | Creating function Pricer.*...
# \ Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ / Creating function Pricer.*...
# | Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ \ Creating function Pricer.*...
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ / Creating function Pricer.*...
# / Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
# - Creating objects...
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
#
# âœ“ Created objects.
# â”œâ”€â”€ ðŸ”¨ Created mount
# â”‚   F:\llm_projects\llm_engineering\AgenticAI-Pricer\pricer_service.py
# â”œâ”€â”€ ðŸ”¨ Created function Pricer.download_model_to_folder.
# â””â”€â”€ ðŸ”¨ Created function Pricer.*.
# âœ“ App deployed in 302.781s! ðŸŽ‰
#
# View Deployment:
# https://modal.com/apps/sameer123khadatkar/main/deployed/pricer-service

# %%
pricer = modal.Cls.from_name("pricer-service", "Pricer")

# %%
pricer().price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0
